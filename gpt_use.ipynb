# %% [markdown]
# Для того, чтобы воспользоваться критерием хи-квадрат пирсона для проверки на независимость двух признаков мне необходимо было создать таблицу сопряженности. Мой запрос в chatgpt выглядел так: "как в питоне создать матрицу, где на пересечении будет лежать количество таких значений из датафрейма, которое соответствует значению 1 признака и попадает в промежуток по 2 признаку?". Chatgpt выдал мне код с использованием функции pd.crosstab, которой я и воспользовалась при проверке гипотезы.

# %% [markdown]
# В блоке машинного обучения я захотела посмотреть на те признаки, которые занулились в lasso-регрессии. Однако метод coef_ не работал, так как регрессия была частью pipeline. Я задала вопрос: "как найти коэффициенты у лассо-регрессии, если она лежит в pipeline?".

# %%
from IPython.display import Image
Image(filename='gpt.photo.png')

# %% [markdown]
# В блоке проверки гипотез спросила: "как в питоне проверить гипотезу о том, что цена не зависит от вариации цветов телефона, зная сколько есть возможных цветов у каждого бренда телефона и сколько стоят телефоны этого бренда?". GPT выдал мне сообщение о том, что можно воспользоваться методом one-way ANOVA + пример кода.

# %% [markdown]
# В блоке машинного обучения спросила: "как подобрать гиперпараметры для градиентного бустинга в питоне?". Chat GPT выдал мне ответ, где подбирались гиперпараметры, однако там использовалась простая модель, а я использовала Pipeline, где вначале скалировала, а затем уже применяла модель. Поэтому я уточнила: "а если у меня модель - часть pipeline, то как мне подобрать гиперпараметр для XGBRegressor". Chat GPT выдал мне уже более подходящий ответ, который я и использовала в своем коде. Метод заключался в том, чтобы при создании сетки гиперпараметров перед названием каждого параметра написать название той части Pipeline, к котором нужно применить поиск по решетке.
